# %% [markdown]
# <a href="https://colab.research.google.com/github/lukasztracz195/DeepLearningInPythonCourse/blob/main/kvasir_dataset_VGG16_transfer_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Wykorzystanie już wytrenowanego modelu VGG16 do klasyfikacji datasetu kvasir

# %% [markdown]
# #1. Przygotowanie środowiska

# %% [markdown]
# ##1.1 Sprawdzenie wersji pythona zainstalowanej na serwerze Google Colaboratory

# %%
# !python --version
# Out:
# Python 3.7.12

# %% [markdown]
# ##1.2 Instalcja odpowiedniej wersji pakietu Tensorflow

# %%
#To determine which version you're using:
# !pip show tensorflow

# For a specific version:
# !pip install tensorflow==2.4.1
# Out:
# Name: tensorflow
# Version: 2.6.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: termcolor, h5py, tensorflow-estimator, grpcio, google-pasta, opt-einsum, keras-preprocessing, six, astunparse, protobuf, tensorboard, typing-extensions, gast, wrapt, wheel, clang, numpy, keras, flatbuffers, absl-py
# Required-by: kapre
# Collecting tensorflow==2.4.1
#   Downloading tensorflow-2.4.1-cp37-cp37m-manylinux2010_x86_64.whl (394.3 MB)
#      |████████████████████████████████| 394.3 MB 14 kB/s
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.12)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.1.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.1.2)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.6.3)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (3.17.3)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (0.37.0)
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Collecting tensorflow-estimator<2.5.0,>=2.4.0
#   Downloading tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 50.0 MB/s
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (0.2.0)
# Collecting h5py~=2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 31.1 MB/s
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (3.7.4.3)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (3.3.0)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.19.5)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (0.12.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.12.1)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.15.0)
# Requirement already satisfied: tensorboard~=2.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (2.6.0)
# Collecting grpcio~=1.32.0
#   Downloading grpcio-1.32.0-cp37-cp37m-manylinux2014_x86_64.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 37.0 MB/s
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (3.3.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (1.8.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (57.4.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (1.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (1.35.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.1) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.1) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.1) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4.1) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.1) (4.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.1) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.1) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.1) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4.1) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.1) (3.5.0)
# Installing collected packages: grpcio, tensorflow-estimator, h5py, gast, tensorflow
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.40.0
#     Uninstalling grpcio-1.40.0:
#       Successfully uninstalled grpcio-1.40.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.6.0
#     Uninstalling tensorflow-estimator-2.6.0:
#       Successfully uninstalled tensorflow-estimator-2.6.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
#       Successfully uninstalled gast-0.4.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.6.0
#     Uninstalling tensorflow-2.6.0:
#       Successfully uninstalled tensorflow-2.6.0
# Successfully installed gast-0.3.3 grpcio-1.32.0 h5py-2.10.0 tensorflow-2.4.1 tensorflow-estimator-2.4.0

# %% [markdown]
# ##1.3 Instalcja odpowiedniej wersji pakietu keras

# %%
# !pip3 install keras==2.4.3
# !pip3 show keras
# Out:
# Collecting keras==2.4.3
#   Downloading Keras-2.4.3-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras==2.4.3) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras==2.4.3) (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras==2.4.3) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras==2.4.3) (1.19.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py->keras==2.4.3) (1.15.0)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.6.0
#     Uninstalling keras-2.6.0:
#       Successfully uninstalled keras-2.6.0
# Successfully installed keras-2.4.3
# Name: Keras
# Version: 2.4.3
# Summary: Deep Learning for humans
# Home-page: https://github.com/keras-team/keras
# Author: Francois Chollet
# Author-email: francois.chollet@gmail.com
# License: MIT
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: pyyaml, h5py, scipy, numpy
# Required-by: keras-vis

# %% [markdown]
# ##1.4 Podłączenie się do dysku Google (Obcjonalne by móc zapisywać utworzone pliki)

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# # 2. Przygotowanie danych

# %% [markdown]
# ##2.1 Zdefiniowanie linków do datasetów kvasir

# %%
kvasir_dataset_v1 = "https://datasets.simula.no/kvasir/data/kvasir-dataset.zip"
extracted_features_kvasir_dataset_v1 = "https://datasets.simula.no/kvasir/data/kvasir-dataset-features.zip"
kvasir_datset_v2 = "https://datasets.simula.no/kvasir/data/kvasir-dataset-v2.zip"
extracted_features_kvasir_dataset_v2 = "https://datasets.simula.no/kvasir/data/kvasir-dataset-v2-features.zip"
kvasir_dataset_v2_folds = "https://datasets.simula.no/kvasir/data/kvasir-dataset-v2-folds.zip"
extracted_features_kvasir_dataset_v2_folds = "https://datasets.simula.no/kvasir/data/kvasir-dataset-v2-folds-features.zip"
kvasir_dataset_v2_folds_additional_set = "https://datasets.simula.no/kvasir/data/kvasir-dataset-v2-folds-additional-classes.zip"
extracted_features_kvasir_dataset_v2_folds_additional_set = "https://datasets.simula.no/kvasir/data/kvasir-dataset-v2-folds-additional-classes-features.zip"

# %% [markdown]
# ##2.2 Pobranie i rozpakowanie danych kvasir_dataset_v1

# %%
# !wget -nc {kvasir_dataset_v1}
# !unzip kvasir-dataset.zip
# Out:
# --2021-09-21 21:21:03--  https://datasets.simula.no/kvasir/data/kvasir-dataset.zip
# Resolving datasets.simula.no (datasets.simula.no)... 128.39.36.14
# Connecting to datasets.simula.no (datasets.simula.no)|128.39.36.14|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1236208343 (1.2G) [application/zip]
# Saving to: ‘kvasir-dataset.zip’
#
# kvasir-dataset.zip  100%[===================>]   1.15G  6.27MB/s    in 3m 15s
#
# 2021-09-21 21:24:19 (6.05 MB/s) - ‘kvasir-dataset.zip’ saved [1236208343/1236208343]
#
# Archive:  kvasir-dataset.zip
#    creating: kvasir-dataset/
#    creating: kvasir-dataset/polyps/
#   inflating: kvasir-dataset/polyps/896dccb7-7df2-4c6d-9c75-9c201a70eb22.jpg
#   inflating: kvasir-dataset/polyps/89530f9a-3694-4dd0-b51a-b8d936b1f411.jpg
#   inflating: kvasir-dataset/polyps/69a27f9e-e92d-4054-adaa-405eeace8b2a.jpg
#   inflating: kvasir-dataset/polyps/9f997a2b-7c3a-422a-8dc6-2e6e87ca45a6.jpg
#   inflating: kvasir-dataset/polyps/d9a0874a-990a-4bc6-9e42-62e2b6e65381.jpg
#   inflating: kvasir-dataset/polyps/1c236874-556c-402d-9709-c5c1672ec14a.jpg
#   inflating: kvasir-dataset/polyps/0c1b433f-75b4-4dc0-8ea0-2eaac21593a7.jpg
#   inflating: kvasir-dataset/polyps/30058222-dbb6-40c4-b466-7a4e1d7e098c.jpg
#   inflating: kvasir-dataset/polyps/3a294535-a9d2-4d0f-b98f-0f4d7e5bb1fd.jpg
#   inflating: kvasir-dataset/polyps/b3a01269-1dc6-43a0-9d5e-1861db87d8be.jpg
#   inflating: kvasir-dataset/polyps/2a2edeab-7a81-44ce-a57f-342b8acbac4c.jpg
#   inflating: kvasir-dataset/polyps/5cc943b0-5113-49b0-b8cd-5cb4cf045d58.jpg
#   inflating: kvasir-dataset/polyps/d9d2be52-ffc8-4dcc-8769-7a001dd1750b.jpg
#   inflating: kvasir-dataset/polyps/0014d89e-5afa-4186-99f9-4400c8c58a18.jpg
#   inflating: kvasir-dataset/polyps/7912d44a-1cd9-4a59-8c7d-b63ce2f63776.jpg
#   inflating: kvasir-dataset/polyps/0e68fc5b-beaa-4607-a13a-f6db84121c78.jpg
#   inflating: kvasir-dataset/polyps/d99161df-3a1a-4005-807e-9a050b04b880.jpg
#   inflating: kvasir-dataset/polyps/1a71959b-7a92-422e-bbf9-5a91cd128ffd.jpg
jpg
#   inflating: kvasir-dataset/ulcerative-colitis/ae68bef5-8ca4-42fd-a275-d34ee4ea8c14_00000074.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/dc65cd9d-bc05-4329-b024-f51692efde4e.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/e8d47686-43c1-4ae7-837a-caf6f2713618.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/98631a86-77cc-4aaf-91e8-be0d3b9ae3d0.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/d9bb4634-2190-4553-9c24-090d3db53bb4.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/584f1fa0-9bb9-49d3-b412-c42819d0a200_00000531.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/7d25538a-c877-497e-b465-499685c69b1d.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/584f1fa0-9bb9-49d3-b412-c42819d0a200_00002716.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/41da6f0b-31a4-40f3-833c-061762702265.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/68bd18ae-3edf-4b60-bfcf-37d727cb840b.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/66ea412c-257b-4762-9685-b6d6b41b618d.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/584f1fa0-9bb9-49d3-b412-c42819d0a200_00002564.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/3086c0ca-b5da-4222-89ec-3ab6a2405b3c.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/584f1fa0-9bb9-49d3-b412-c42819d0a200_00002130.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/676e3ee0-e546-4393-b640-2a8defaeb107.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/29c4b403-3d24-4227-8c62-6cfd9ed3ba9b.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/c3a25804-3627-4bc6-b540-c442b0a48533.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/c636dae1-319d-44e5-b834-62cfefbd0be4.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/b26076a1-8796-4a93-8bc5-efd76009bda9.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/ea311a55-94c4-4fa5-92cf-759e9595881c.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/bf16beb2-a1d7-4dc9-a107-50bbccb8bedc.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/c05dfeea-931b-46f0-859f-1856678edee8.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/fc79c489-b358-4368-b965-330615af73d4_00000298.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/4429f56f-551d-4413-949f-7b17a40fcf01.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/c801eb98-6af7-4a43-b23c-0351cffaca3b_00000465.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/c0f57402-ad88-44e2-a0dc-3f6cbef7a87b.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/b6c03496-cfc7-4e51-9234-7a01389f08f1.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/834bbc38-6746-467a-b9be-c40334513318.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/d4ba1772-76f0-420b-bb48-9a4b8b7ed4a4.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/797e3c48-c31f-47a6-b4c5-c1d7e02183c6.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/fdb9af61-5fba-4712-8127-e96637037408.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/7f3395c1-f54d-43db-9902-3570bd24ef5d.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/8c095b85-d5fb-41af-8a61-19eed635048c.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/27f8a230-2d6d-4a89-a77e-58f840878123.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/959124ce-d4ca-4f2d-a3c4-39a021223e2f.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/584f1fa0-9bb9-49d3-b412-c42819d0a200_00001360.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/b17fa5d5-8e85-42e6-ba6d-403822972f04.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/fded0688-c4cd-4aad-980b-f55e161f1b44.jpg
#   inflating: kvasir-dataset/ulcerative-colitis/6bb0c7be-0347-4497-a424-7b9e93b54bc7.jpg

# %% [markdown]
# ## 2.3 Sprawdzenie rozmiaru i formatu danych

# %% [markdown]
# ###2.3.1 Przygotowanie funkcji do sprawdzenia rozmiaru obrazu

# %%
def get_set_sizes_of_images_and_extesions_in_exist_in_location(path_to_directory_with_images):
    import os
    import cv2
    from os import listdir
    set_of_sizes = set()
    set_of_extensions = set()
    for filename_with_extension in listdir(path_to_directory_with_images):
        filename_extension_tuple = os.path.splitext(filename_with_extension)
        filename = filename_extension_tuple[0]
        extension = filename_extension_tuple[1]
        path = path_to_directory_with_images + "/" + filename_with_extension
        image_data = cv2.imread(path)
        if image_data.shape not in set_of_sizes:
            set_of_sizes.add(image_data.shape)
        if extension not in set_of_extensions:
            set_of_extensions.add(extension)
    return set_of_sizes, set_of_extensions

# %% [markdown]
# ###2.3.2 Sprawdzenie jakimi rozmiarami i formatami obrazów dysponujemy

# %%
global_path = "/content"
path_to_dataset = "kvasir-dataset"
classes = ["dyed-lifted-polyps", "dyed-resection-margins", "esophagitis", "normal-cecum", "normal-pylorus", "normal-z-line", "polyps", "ulcerative-colitis"]
for class_name in classes:
    path_to_directory  = global_path + "/" + path_to_dataset + "/" + class_name
    set_of_sizes, set_of_extensions = get_set_sizes_of_images_and_extesions_in_exist_in_location(path_to_directory)
    message = "class_name_directory: %s | sizes_of_size_images: %s | extensions: %s" % (class_name, set_of_sizes, set_of_extensions)
    print(message)
# Out:
# class_name_directory: dyed-lifted-polyps | sizes_of_size_images: {(1072, 1920, 3), (576, 720, 3)} | extensions: {'.jpg'}
# class_name_directory: dyed-resection-margins | sizes_of_size_images: {(576, 720, 3)} | extensions: {'.jpg'}
# class_name_directory: esophagitis | sizes_of_size_images: {(576, 720, 3), (1072, 1920, 3), (1024, 1280, 3)} | extensions: {'.jpg'}
# class_name_directory: normal-cecum | sizes_of_size_images: {(576, 720, 3)} | extensions: {'.jpg'}
# class_name_directory: normal-pylorus | sizes_of_size_images: {(576, 720, 3), (1072, 1920, 3), (1024, 1280, 3)} | extensions: {'.jpg'}
# class_name_directory: normal-z-line | sizes_of_size_images: {(576, 720, 3), (1072, 1920, 3), (1024, 1280, 3)} | extensions: {'.jpg'}
# class_name_directory: polyps | sizes_of_size_images: {(1072, 1920, 3), (1024, 1280, 3), (576, 720, 3)} | extensions: {'.jpg'}
# class_name_directory: ulcerative-colitis | sizes_of_size_images: {(1080, 1350, 3), (1072, 1920, 3), (1024, 1280, 3), (576, 720, 3)} | extensions: {'.jpg'}

# %% [markdown]
# ### 2.3.2 Dane jakimi dysponujemy wyamgają ujednolicenia ich do tego samego rozmiaru by móc ich użyć w modelu sieci neuronowej

# %% [markdown]
# ##2.4 Zmiana rozmiarów obrazów w datasecie

# %% [markdown]
# ###2.4.1 Utowrzenie funckji do zmainy rozmiaru obrazu

# %%
def resize_image(src_img, target_size=(64,64), bg_color="black", color_format="RGB"): 
    from PIL import Image

    # rescale the image so the longest edge is the right size
    src_img.thumbnail(target_size, Image.ANTIALIAS)

    # Create a new image of the right shape
    new_image = Image.new(color_format, target_size, bg_color)

    # Paste the rescaled image onto the new centered background
    new_image.paste(src_img, (int((target_size[0] - src_img.size[0]) / 2), int((target_size[1] - src_img.size[1]) / 2)))

    # return the resized image
    return new_image

# %% [markdown]
# ###2.4.2 Zmiana rozmiaru obrazów na żadany w datasecie

# %%
TARGET_SIZE = (224,224)

# %%
from PIL import Image
from os import listdir



global_path = "/content"
path_to_dataset = "kvasir-dataset"
classes = ["dyed-lifted-polyps", "dyed-resection-margins", "esophagitis", "normal-cecum", "normal-pylorus", "normal-z-line", "polyps", "ulcerative-colitis"]
for class_name in classes:
    path_to_directory  = global_path + "/" + path_to_dataset + "/" + class_name
    for filename_with_extension in listdir(path_to_directory):
        path_to_image  = global_path + "/" + path_to_dataset + "/" + class_name + "/" + filename_with_extension
        img = Image.open(path_to_image)
        resized_img = resize_image(img, target_size=TARGET_SIZE)
        resized_img.save(path_to_image)

# %% [markdown]
# ###2.4.3 Sprawdzenie czy zmiana rozmiaru danych się powiodła

# %%
global_path = "/content"
path_to_dataset = "kvasir-dataset"
classes = ["dyed-lifted-polyps", "dyed-resection-margins", "esophagitis", "normal-cecum", "normal-pylorus", "normal-z-line", "polyps", "ulcerative-colitis"]
for class_name in classes:
    path_to_directory  = global_path + "/" + path_to_dataset + "/" + class_name
    set_of_sizes, set_of_extensions = get_set_sizes_of_images_and_extesions_in_exist_in_location(path_to_directory)
    message = "class_name_directory: %s | sizes_of_size_images: %s | extensions: %s" % (class_name, set_of_sizes, set_of_extensions)
    print(message)
# Out:
# class_name_directory: dyed-lifted-polyps | sizes_of_size_images: {(224, 224, 3)} | extensions: {'.jpg'}
# class_name_directory: dyed-resection-margins | sizes_of_size_images: {(224, 224, 3)} | extensions: {'.jpg'}
# class_name_directory: esophagitis | sizes_of_size_images: {(224, 224, 3)} | extensions: {'.jpg'}
# class_name_directory: normal-cecum | sizes_of_size_images: {(224, 224, 3)} | extensions: {'.jpg'}
# class_name_directory: normal-pylorus | sizes_of_size_images: {(224, 224, 3)} | extensions: {'.jpg'}
# class_name_directory: normal-z-line | sizes_of_size_images: {(224, 224, 3)} | extensions: {'.jpg'}
# class_name_directory: polyps | sizes_of_size_images: {(224, 224, 3)} | extensions: {'.jpg'}
# class_name_directory: ulcerative-colitis | sizes_of_size_images: {(224, 224, 3)} | extensions: {'.jpg'}

# %% [markdown]
# ###2.5 Podział danych na treningowe i testowe

# %%
import os
import numpy as np
import shutil
import random
global_path = "/content"
path_to_dataset = "kvasir-dataset"
root_dir = global_path + "/" + path_to_dataset + "/"
classes_dir = ["dyed-lifted-polyps", "dyed-resection-margins", "esophagitis", "normal-cecum", "normal-pylorus", "normal-z-line", "polyps", "ulcerative-colitis"]

test_ratio = 0.20

for cls in classes_dir:
    os.makedirs(root_dir +'train/' + cls)
    os.makedirs(root_dir +'test/' + cls)

src = root_dir + cls

allFileNames = os.listdir(src)
np.random.shuffle(allFileNames)
train_FileNames, test_FileNames = np.split(np.array(allFileNames),
                                                          [int(len(allFileNames)* (1 - test_ratio))])


train_FileNames = [src+'/'+ name for name in train_FileNames.tolist()]
test_FileNames = [src+'/' + name for name in test_FileNames.tolist()]

print("*****************************")
print('Total images: ', len(allFileNames))
print('Training: ', len(train_FileNames))
print('Testing: ', len(test_FileNames))
print("*****************************")


lab = classes_dir

for name in train_FileNames:
    for i in lab:
        shutil.copy(name, root_dir +'train/' + i)

for name in test_FileNames:
    for i in lab:
        shutil.copy(name, root_dir +'test/' + i)
print("Copying Done!")
# Out:
# *****************************
# Total images:  500
# Training:  400
# Testing:  100
# *****************************
# Copying Done!

# %% [markdown]
# ## 2.6 Przygotowanie datasetu zgodnie z api kerasa

# %%
from tensorflow import keras
from tensorflow.keras.preprocessing import image_dataset_from_directory

global_path = "/content"
path_to_dataset = "kvasir-dataset"
root_dir = global_path + "/" + path_to_dataset + "/"

train_ds = image_dataset_from_directory(
    directory=root_dir + "train/",
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=TARGET_SIZE)
test_ds = image_dataset_from_directory(
    directory=root_dir + "test/",
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=TARGET_SIZE)
# Out:
# Found 3200 files belonging to 8 classes.
# Found 800 files belonging to 8 classes.

# %% [markdown]
# #3. Opracowywanie modelu sieci neuronowej bazując na VGG16

# %% [markdown]
# ##3.1 Przygotowanie modelu wytrenowanej już sieci VGG16

# %%
import os
import numpy as np
import random

import keras
from keras.applications.vgg16 import VGG16
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Activation, Input
from keras.layers import Conv2D, MaxPooling2D
from keras.models import Model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input

import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

vgg = keras.applications.VGG16(weights='imagenet', include_top=True)
vgg.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 5s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##3.2 Zmiana warstwy wyjściowej sieci VGG16 by zwracała 8 klas

# %%
input_shape = (TARGET_SIZE[0],TARGET_SIZE[1],3)
nClasses = 8
print("INPUT_SHAPE: ", input_shape)
# make a reference to VGG's input layer
inp = vgg.input

# make a new softmax layer with num_classes neurons
new_classification_layer = Dense(nClasses, activation='softmax')

# connect our new layer to the second to last layer in VGG, and make a reference to it
out = new_classification_layer(vgg.layers[-2].output)

# create a new network between inp and out
model_new = Model(inp, out)
model_new.summary()
# Out:
# INPUT_SHAPE:  (224, 224, 3)
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 32776
# =================================================================
# Total params: 134,293,320
# Trainable params: 134,293,320
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##3.3 Wyłączenie trenowania dla warstw sieci VGG16 wszystkich prócz ostatniej

# %%
# make all layers untrainable by freezing weights (except for last layer)
for l, layer in enumerate(model_new.layers[:-1]):
    layer.trainable = False

# ensure the last layer is trainable/not frozen
for l, layer in enumerate(model_new.layers[-1:]):
    layer.trainable = True

model_new.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model_new.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 32776
# =================================================================
# Total params: 134,293,320
# Trainable params: 32,776
# Non-trainable params: 134,260,544
# _________________________________________________________________

# %% [markdown]
# #4 Trenowanie sieci neuronowej

# %% [markdown]
# ##4.1 Zdefiniowanie callbacków dla naszej sieci

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
my_callbacks = [
    # EarlyStopping(monitor='val_loss',min_delta=0.1, patience=5, verbose=1, mode='auto'),
    # EarlyStopping(monitor='val_accuracy',min_delta=0.01, patience=5, verbose=1 ,mode='auto')
]

# %% [markdown]
# ##4.2 Dotrenowywanie naszej sieci VGG16 do naszego problemu

# %%
batch_size = 128
epochs = 100
history = model_new.fit(train_ds,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=test_ds,
                    callbacks=my_callbacks)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 35s 352ms/step - loss: 2.4991 - accuracy: 0.0834 - val_loss: 2.4343 - val_accuracy: 0.1250
# Epoch 2/100
# 100/100 [==============================] - 35s 350ms/step - loss: 2.5472 - accuracy: 0.0894 - val_loss: 2.5142 - val_accuracy: 0.1250
# Epoch 3/100
# 100/100 [==============================] - 35s 351ms/step - loss: 2.5254 - accuracy: 0.0881 - val_loss: 2.3443 - val_accuracy: 0.1250
# Epoch 4/100
# 100/100 [==============================] - 35s 351ms/step - loss: 2.5196 - accuracy: 0.0866 - val_loss: 2.3495 - val_accuracy: 0.1250
# Epoch 5/100
# 100/100 [==============================] - 35s 351ms/step - loss: 2.
# 100/100 [==============================] - 36s 355ms/step - loss: 2.5208 - accuracy: 0.0772 - val_loss: 2.3460 - val_accuracy: 0.1250
# Epoch 92/100
# 100/100 [==============================] - 36s 354ms/step - loss: 2.5000 - accuracy: 0.0825 - val_loss: 2.4878 - val_accuracy: 0.1250
# Epoch 93/100
# 100/100 [==============================] - 36s 353ms/step - loss: 2.5281 - accuracy: 0.0859 - val_loss: 2.3492 - val_accuracy: 0.1250
# Epoch 94/100
# 100/100 [==============================] - 36s 356ms/step - loss: 2.5127 - accuracy: 0.0800 - val_loss: 2.3215 - val_accuracy: 0.1250
# Epoch 95/100
# 100/100 [==============================] - 36s 355ms/step - loss: 2.5035 - accuracy: 0.0834 - val_loss: 2.3181 - val_accuracy: 0.1250
# Epoch 96/100
# 100/100 [==============================] - 36s 354ms/step - loss: 2.5477 - accuracy: 0.0737 - val_loss: 2.4147 - val_accuracy: 0.1250
# Epoch 97/100
# 100/100 [==============================] - 36s 354ms/step - loss: 2.5602 - accuracy: 0.0787 - val_loss: 2.4460 - val_accuracy: 0.1250
# Epoch 98/100
# 100/100 [==============================] - 36s 355ms/step - loss: 2.5548 - accuracy: 0.0856 - val_loss: 2.4498 - val_accuracy: 0.1250
# Epoch 99/100
# 100/100 [==============================] - 36s 356ms/step - loss: 2.5132 - accuracy: 0.0859 - val_loss: 2.3745 - val_accuracy: 0.1250
# Epoch 100/100
# 100/100 [==============================] - 36s 355ms/step - loss: 2.5237 - accuracy: 0.0844 - val_loss: 2.7275 - val_accuracy: 0.1250

# %% [markdown]
# #5. Przegląd wyników uczenia się naszej sieci

# %% [markdown]
# ##5.1 Zdefiniowanie funkcji do rysowania wykresów dla funckji straty i funckji dokładności

# %%
def make_accuracy_plot(history):
  
    #   Funckja zwraca wykres dokładności (accuracy) modelu na zbiorze treningowym i walidacyjnym.
    

    import matplotlib.pyplot as plt
    import seaborn as sns
    sns.set()
    acc, val_acc = history.history['accuracy'], history.history['val_accuracy']
    epochs = range(1, len(acc)+1)

    plt.figure(figsize=(10,8))
    plt.plot(epochs, acc, label='Dokladność trenowania', marker='o')
    plt.plot(epochs, val_acc, label='Dokladność walidacji', marker='o')
    plt.legend()
    plt.title('Dokładność trenowania i walidacji')
    plt.xlabel('Epoki')
    plt.ylabel('Dokładność')
    plt.show()

def make_loss_plot(history):

    #   Funkjca zwraca wykres straty (loss) modelu na zbiorze treningowym
    #   i walidacyjnym


    import matplotlib.pyplot as plt
    import seaborn as sns
    sns.set()
    loss, val_loss = history.history['loss'], history.history['val_loss']
    epochs = range(1, len(loss)+ 1)

    plt.figure(figsize = (10,8))
    plt.plot(epochs, loss, label='Strata trenowania', marker='o')
    plt.plot(epochs, val_loss, label="Strata walidacji", marker='o')
    plt.legend()
    plt.title('Strata trenowania i walidacji')
    plt.xlabel('Epoki')
    plt.ylabel('Strata')
    plt.show()

# %% [markdown]
# ## 5.2 Wykres dokładności trenowanie i walidacji

# %%
make_accuracy_plot(history)

# %% [markdown]
# ##5.3 Wykres straty trenowania i walidacji

# %%
make_loss_plot(history)
